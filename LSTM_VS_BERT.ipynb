# %% [markdown]
# **LSTM**

# %%
from sklearn import metrics
# accuracy: (tp + tn) / (p + n)
accuracy = metrics.accuracy_score(test_labels, Y_predictedClass)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = metrics.precision_score(test_labels, Y_predictedClass)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = metrics.recall_score(test_labels, Y_predictedClass)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = metrics.f1_score(test_labels, Y_predictedClass)
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.912168
# Precision: 0.926072
# Recall: 0.946541
# F1 score: 0.936195

# %%
print('Clasification report:\n', metrics.classification_report(test_labels, Y_predictedClass))
# Out:
# Clasification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      6386
#            1       0.93      0.95      0.94     13618
#
#     accuracy                           0.91     20004
#    macro avg       0.90      0.89      0.90     20004
# weighted avg       0.91      0.91      0.91     20004

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
cm = metrics.confusion_matrix(test_labels, Y_predictedClass)

plt.imshow(cm, cmap=plt.cm.Blues)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.xticks([], [])
plt.yticks([], [])
plt.title('Confusion matrix ')
plt.colorbar()
plt.show()

# %%
from sklearn.metrics import roc_curve,roc_auc_score
fpr , tpr , thresholds = roc_curve (test_labels, Y_predictedProba)

# %%
def plot_roc_curve(fpr,tpr): 
  plt.plot(fpr,tpr) 
  plt.axis([0,1,0,1]) 
  plt.xlabel('False Positive Rate') 
  plt.ylabel('True Positive Rate') 
  plt.show()    
  
plot_roc_curve (fpr,tpr)

# %% [markdown]
# **BERT Transformers**

# %%
from sklearn import metrics
test_labels = list(test.labels)
# accuracy: (tp + tn) / (p + n)
accuracy = metrics.accuracy_score(test_labels, predictions)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = metrics.precision_score(test_labels, predictions)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = metrics.recall_score(test_labels, predictions)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = metrics.f1_score(test_labels, predictions)
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.932000
# Precision: 0.936950
# Recall: 0.962349
# F1 score: 0.949480

# %%
print('Clasification report:\n', metrics.classification_report(test_labels, predictions))
# Out:
# Clasification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.87      0.90       336
#            1       0.94      0.96      0.95       664
#
#     accuracy                           0.93      1000
#    macro avg       0.93      0.92      0.92      1000
# weighted avg       0.93      0.93      0.93      1000

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
cm = metrics.confusion_matrix(test_labels, predictions)

plt.imshow(cm, cmap=plt.cm.Blues)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.xticks([], [])
plt.yticks([], [])
plt.title('Confusion matrix ')
plt.colorbar()
plt.show()

# %%
from sklearn.metrics import roc_curve,roc_auc_score
fpr , tpr , thresholds = roc_curve (test_labels, predictions)

# %%
def plot_roc_curve(fpr,tpr): 
  plt.plot(fpr,tpr) 
  plt.axis([0,1,0,1]) 
  plt.xlabel('False Positive Rate') 
  plt.ylabel('True Positive Rate') 
  plt.show()    
  
plot_roc_curve (fpr,tpr)

# %% [markdown]
# **Conclusion**
#
# The LSTM model starts overfitting early during the training process compared to the BERT model, which means the BERT model has even more potential. But in our case, BERT performed a little better than LSTM but no significant difference, partly because I did not reach the point right before the BERT starts overfitting but mostly because they both performed well on this particular dataset.

# %% [markdown]
# Using the LSTM model is more demanding than BERT. To use LSTM effectively, the following process is necessary, you need to clean the text (remove stopwords, URLs, emojis, punctuation, HTML tags), then do word stemming(replace words by their root form), then fit the tokenizer to your resulting vocabulary in the intention of converting words to numbers, finally you encode your sentences. Now, the data is ready to train your LSTM model.
#
# Whereas for the BERT model you just need to apply the BERT tokenizer to your sentences, and yes, your data is ready to fine-tune the pretrained BERT model.

# %% [markdown]
# So, using the BERT model is overall a better option than LSTM!
